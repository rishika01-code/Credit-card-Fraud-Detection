# %% [markdown]
# <a href="https://colab.research.google.com/github/rishika01-code/Credit-card-Fraud-Detection/blob/main/Credit_card_Fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('/content/creditcard.csv')
# print(dataset.head(10))
dataset.drop(columns=['Time'],axis=1,inplace= True)
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19898 entries, 0 to 19897
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      19898 non-null  float64
#  1   V2      19898 non-null  float64
#  2   V3      19898 non-null  float64
#  3   V4      19898 non-null  float64
#  4   V5      19898 non-null  float64
#  5   V6      19898 non-null  float64
#  6   V7      19898 non-null  float64
#  7   V8      19898 non-null  float64
#  8   V9      19898 non-null  float64
#  9   V10     19898 non-null  float64
#  10  V11     19897 non-null  float64
#  11  V12     19897 non-null  float64
#  12  V13     19897 non-null  float64
#  13  V14     19897 non-null  float64
#  14  V15     19897 non-null  float64
#  15  V16     19897 non-null  float64
#  16  V17     19897 non-null  float64
#  17  V18     19897 non-null  float64
#  18  V19     19897 non-null  float64
#  19  V20     19897 non-null  float64
#  20  V21     19897 non-null  float64
#  21  V22     19897 non-null  float64
#  22  V23     19897 non-null  float64
#  23  V24     19897 non-null  float64
#  24  V25     19897 non-null  float64
#  25  V26     19897 non-null  float64
#  26  V27     19897 non-null  float64
#  27  V28     19897 non-null  float64
#  28  Amount  19897 non-null  float64
#  29  Class   19897 non-null  float64
# dtypes: float64(30)
# memory usage: 4.6 MB
# None

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#check dataset is balanced or imbalaced
print(dataset['Class'].value_counts())
# Out:
# Class
# 0.0    19812
# 1.0       85
# Name: count, dtype: int64

# %% [markdown]
# Fraud =1 Legit =0

# %%
print(dataset.describe())
# Out:
#                  V1            V2            V3            V4            V5  \
# count  19898.000000  19898.000000  19898.000000  19898.000000  19898.000000
# mean      -0.244326      0.242420      0.745774      0.277011     -0.163264
# std        1.889986      1.527342      1.767726      1.466218      1.430821
# min      -30.552380    -40.978852    -31.103685     -5.172595    -32.092129
# 25%       -0.959632     -0.329008      0.309235     -0.636713     -0.745156
# 50%       -0.302521      0.220079      0.898672      0.224608     -0.199377
# 75%        1.164473      0.870117      1.532922      1.142143      0.341367
# max        1.960497     16.713389      4.101716     11.927512     34.099309
#
#                  V6            V7            V8            V9           V10  \
# count  19898.000000  19898.000000  19898.000000  19898.000000  19898.000000
# mean       0.092881     -0.145279      0.022237      0.636382     -0.220463
# std        1.331029      1.338260      1.346813      1.278839      1.219491
# min      -23.496714    -26.548144    -41.484823     -7.175097    -14.166795
# 25%       -0.657306     -0.599403     -0.171779     -0.209565     -0.679812
# 50%       -0.175434     -0.072254      0.023822      0.620176     -0.276776
# 75%        0.486735      0.448572      0.279960      1.409142      0.228545
# max       21.393069     34.303177     20.007208     10.392889     12.701539
#
#        ...           V21           V22           V23           V24  \
# count  ...  19897.000000  19897.000000  19897.000000  19897.000000
# mean   ...     -0.047949     -0.146461     -0.038093      0.010678
# std    ...      0.828385      0.637567      0.520683      0.591180
# min    ...    -20.262054     -8.593642    -26.751119     -2.728650
# 25%    ...     -0.259497     -0.563992     -0.174213     -0.333314
# 50%    ...     -0.115398     -0.118803     -0.046994      0.061181
# 75%    ...      0.049521      0.254057      0.073666      0.398549
# max    ...     22.614889      5.805795     13.876221      3.695503
#
#                 V25           V26           V27           V28        Amount  \
# count  19897.000000  19897.000000  19897.000000  19897.000000  19897.000000
# mean       0.122924      0.033127      0.014454      0.007312     70.271100
# std        0.437675      0.530315      0.393002      0.244372    205.363789
# min       -7.495741     -1.338556     -8.567638     -3.575312      0.000000
# 25%       -0.138325     -0.341917     -0.069146     -0.010879      5.750000
# 50%        0.160495     -0.036546      0.003868      0.019083     16.000000
# 75%        0.400713      0.332729      0.096281      0.077551     59.980000
# max        5.525093      3.517346      8.254376      4.860769   7879.420000
#
#               Class
# count  19897.000000
# mean       0.004272
# std        0.065222
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 30 columns]

# %%
legit = dataset[dataset.Class == 0]
Fraud = dataset[dataset.Class == 1]
print(Fraud.head(10))
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 541  -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 623  -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 4920 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 6108 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 6329  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
# 6331  0.008430  4.137837 -6.240697  6.675732  0.768307 -3.353060 -1.631735
# 6334  0.026779  4.132464 -6.560600  6.348557  1.329666 -2.513479 -1.689102
# 6336  0.329594  3.712889 -5.775935  6.078266  1.667359 -2.420168 -0.812891
# 6338  0.316459  3.809076 -5.615159  6.047445  1.554026 -2.651353 -0.746579
# 6427  0.725646  2.300894 -5.329976  4.007683 -1.730411 -1.732193 -3.968593
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 541   1.391657 -2.770089 -2.772272  ...  0.517232 -0.035049 -0.465211
# 623  -0.067794 -0.270953 -0.838587  ...  0.661696  0.435477  1.375966
# 4920 -0.399147 -0.238253 -1.525412  ... -0.294166 -0.932391  0.172726
# 6108 -0.248778 -0.247768 -4.801637  ...  0.573574  0.176968 -0.436207
# 6329 -0.496358 -1.282858 -2.447469  ... -0.379068 -0.704181 -0.656805
# 6331  0.154612 -2.795892 -6.187891  ...  0.364514 -0.608057 -0.539528
# 6334  0.303253 -3.139409 -6.045468  ...  0.370509 -0.576752 -0.669605
# 6336  0.133080 -2.214311 -5.134454  ...  0.156617 -0.652450 -0.551572
# 6338  0.055586 -2.678679 -4.959493  ...  0.208828 -0.511747 -0.583813
# 6427  1.063728 -0.486097 -4.624985  ...  0.589669  0.109541  0.601045
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00    1.0
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00    1.0
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93    1.0
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00    1.0
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00    1.0
# 6331  0.128940  1.488481  0.507963  0.735822  0.513574    1.00    1.0
# 6334 -0.759908  1.605056  0.540675  0.737040  0.496699    1.00    1.0
# 6336 -0.716522  1.415717  0.555265  0.530507  0.404474    1.00    1.0
# 6338 -0.219845  1.474753  0.491192  0.518868  0.402528    1.00    1.0
# 6427 -0.364700 -1.843078  0.351909  0.594550  0.099372    1.00    1.0
#
# [10 rows x 30 columns]

# %%
new_df = legit.sample(n=492)
print(new_df.head(10))
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 9719   1.183291 -0.112823  0.727943  0.085377 -0.438778  0.138970 -0.629387
# 8445   1.089793 -0.080031  1.009398  1.742636 -0.162398  1.153865 -0.536233
# 1261  -0.770968 -0.070879  0.998146 -1.792216  0.040765 -0.850322  0.489440
# 17812 -0.691397  1.349195  0.710418 -0.011474  0.065634 -0.731778  0.386002
# 3351  -0.503883  0.822325  0.712960  0.502541 -0.460892  0.345623  1.797522
# 3821  -0.286741  1.176355  2.505873  2.804536  0.038571  1.078103  0.011575
# 7257  -0.382006  1.381576  0.190011  1.427781  0.260897  0.184706  0.128886
# 7077  -2.176084  0.485672  1.178898 -0.081746  0.329833 -0.178999 -0.191529
# 3122  -2.666991  1.706734  0.893817 -0.261451 -0.432645 -0.148172  0.315300
# 19127 -2.322521 -2.539144 -1.286760 -2.223798 -9.209556  4.262947  8.526251
#
#              V8        V9       V10  ...       V21       V22       V23  \
# 9719   0.107752  1.508876 -0.392271  ... -0.009636  0.229132 -0.038007
# 8445   0.189578  2.432545 -0.829306  ... -0.592524 -0.987799 -0.044471
# 1261   0.086829 -1.643236  0.323733  ...  0.053904 -0.148724  0.204873
# 17812  0.347037 -0.640520 -0.759483  ... -0.239350 -0.742498 -0.020864
# 3351  -0.291890 -0.576575 -0.452181  ...  0.095028  0.300693 -0.180335
# 3821   0.202091 -0.962279  0.397318  ... -0.030999  0.194469 -0.277251
# 7257   0.200210  0.745167 -0.249804  ... -0.032613  0.037791 -0.235472
# 7077  -0.017327  3.139561  1.098551  ... -0.326254  0.363498 -0.048757
# 3122   0.114472  1.749960  1.997847  ... -0.234102  0.504028 -0.130023
# 19127 -1.174154  1.656442 -3.629438  ... -0.094571  0.267803  1.448860
#
#             V24       V25       V26       V27       V28   Amount  Class
# 9719  -0.293682  0.144555  1.064148 -0.077718 -0.011298    15.95    0.0
# 8445  -0.802777  0.539594 -0.502112  0.065254  0.020702    37.88    0.0
# 1261   0.152901 -0.272694 -0.636777  0.302181  0.185768    64.93    0.0
# 17812 -0.184512 -0.037074  0.104324  0.123452  0.023386     9.99    0.0
# 3351  -0.430406  0.387622 -0.279252  0.008308 -0.041943   250.00    0.0
# 3821  -0.399436 -0.137051  0.232843  0.182048  0.129298     0.00    0.0
# 7257  -1.060090 -0.214293 -0.160769 -0.251824 -0.018104    27.80    0.0
# 7077   0.213171 -0.952755  0.120050  0.235939  0.711928     0.01    0.0
# 3122  -0.067858  0.472748  0.525707  1.102366  1.084765    29.99    0.0
# 19127  0.545259  0.166934 -1.031362  0.860382 -0.335948  2044.02    0.0
#
# [10 rows x 30 columns]

# %%
new_dataset =pd.concat([new_df,Fraud],axis =0)
# print(new_dataset.head(10))
print(new_dataset.shape)
# Out:
# (577, 30)

# %%
x = new_dataset.drop(columns=['Class'],axis = 1)
y = new_dataset['Class']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
print(y_train.head(10))
# Out:
# 5738     0.0
# 15840    0.0
# 541      1.0
# 2510     0.0
# 11764    0.0
# 7155     0.0
# 17812    0.0
# 2996     0.0
# 7631     0.0
# 1822     0.0
# Name: Class, dtype: float64
